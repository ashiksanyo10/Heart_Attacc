# %%
#importing the required library

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp
import seaborn as sns
import re
import os
import time
import plotly.express as px

# %%
#import the dataset 

df = pd.read_csv("../input/heart-attack-analysis-prediction-dataset/heart.csv")

# %%
#know the No. of rows and columns in the dataset 

df.shape

# %%
#show the first top 10 readings of dataset 0-09

df.head(10)

# %%
##show the last 10 readings of dataset 293-302
df.tail(10)

# %%
#coulmn attributes 

df.info()

# %%
#duplicate enrtry

df.loc[df.duplicated()]

# %%
df.loc[df.duplicated()]

# %%
df.isnull().sum()

# %%
df.duplicated().sum()

# %% [markdown]
# Lets know the attributes of the datasets
#
# Age : Age of the patient
#
# Sex : Sex of the patient
#
# exang: exercise induced angina (1 = yes; 0 = no)
# angina refers to  pain in the chest that comes on with exercise, stress, or other things that make the heart work harder
#
# ca: number of major vessels (0-3)
#
# cp : Chest Pain type chest pain type
#
# Value 1: typical angina
#
# Value 2: atypical angina
#
# Value 3: non-anginal pain Value
#
# 4: asymptomatic trtbps : resting blood pressure (in mm Hg)
#
# chol : cholestoral in mg/dl

# %%
#The corr() method calculates the relationship between each column in your data set. 

df.corr()

# %%
#fetch unique age from age attribute

len(df["age"].unique())

# %% [markdown]
# ANALYSIS

# %%
#Ploting the bar graph to visualize the age group

plt.figure(figsize=(18,10))
plt.style.use("ggplot")

#using countplot
sns.countplot(x=df["age"])  

plt.title("Age count",fontsize=20)
plt.xlabel("AGE",fontsize=20)
plt.ylabel("COUNT",fontsize=20)
plt.show()

# %% [markdown]
# Highest Number of patients recorded are of 58

# %%
#Plotting a pie chart to differciate the gender 

s=df["sex"].value_counts().reset_index()
px.pie(s,names="index",values="sex")  #using pie here

# %% [markdown]
# As per the pie chart : total Male patients are 207 & 96 are Female patients

# %%
c=df["cp"].value_counts().reset_index()
c

# %%
#plotting graph to identify the pateint 

plt.figure(figsize=(20,10))
plt.style.use("ggplot")
sns.barplot(x=c["index"],y=c["cp"])   #using bar here for visualization
plt.title("Type of chest pain with reseoct to No. of patients",fontsize=20)
plt.xlabel("TYPE",fontsize=20)
plt.ylabel("COUNT",fontsize=20)
plt.show()

# %% [markdown]
# As per the graph, patients have type Value 1 that is typical angina Value

# %%
plt.figure(figsize=(20,10))
plt.style.use("ggplot")
sns.displot(df["trtbps"])   #using displot here
plt.title("Blood Pressure",fontsize=18)
plt.xlabel("BLOOD PRESSURE",fontsize=20)
plt.ylabel("COUNT",fontsize=20)
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.style.use("ggplot")
sns.displot(df["chol"])
plt.title("Cholestrol Level ",fontsize=18)
plt.xlabel("CHOLESTROL LEVEL",fontsize=20)
plt.ylabel("COUNT",fontsize=20)
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.style.use("ggplot")
sns.displot(df["thalachh"])
plt.title("Heart Rate",fontsize=18)
plt.xlabel("HEART RATE",fontsize=20)
plt.ylabel("COUNT",fontsize=20)
plt.show()

# %% [markdown]
# BIVARIATE-ANALYSIS

# %%
df[["age","output"]].value_counts().sort_values()

# %%
v=pd.crosstab(df["age"],df["output"]).reset_index()

v.columns=["age","low_risk","high_risk"]
v

# %%
px.line(v,v["age"],v["high_risk"],title="Risk of heart attack with age")

# %%
px.line(v,v["age"],v["low_risk"],title="Risk of low heart attack with age")

# %%
plt.figure(figsize=(20,10))
plt.style.use("ggplot")
sns.lineplot(y="trtbps",x="age",data=df)
plt.title("Blood pressure with respect to Patient age",fontsize=20)
plt.xlabel("AGE",fontsize=20)
plt.ylabel("BLOOD PRESSURE",fontsize=20)
plt.show()

# %% [markdown]
# As per the graph there is high chance of increasein the Blood pressure with increase in the age.

# %%
plt.figure(figsize=(20,10))
plt.style.use("ggplot")
sns.lineplot(y="chol",x="age",data=df)
plt.title("Cholestrol level with age",fontsize=20)
plt.xlabel("AGE",fontsize=20)
plt.ylabel("CHOLESTROL LEVEL",fontsize=20)
plt.show()

# %% [markdown]
# As per the graph there is a  high chance of cholestrol level in body with increase in the age

# %%
plt.figure(figsize=(20,10))
plt.style.use("ggplot")
sns.lineplot(y="thalachh",x="age",data=df)
plt.title("HEART RATE  WITH AGE",fontsize=20)
plt.xlabel("AGE",fontsize=20)
plt.ylabel("HEART RATE",fontsize=20)
plt.show()

# %% [markdown]
# As per the graph : Increase in patients age, The heart rate is low

# %%
#DOES INCREASE IN CHOLESTROL LEVEL IN BODY HAVE ANY EFFECT TOWARDS THE HEART ATTACK:

plt.figure(figsize=(10,6))
plt.style.use("ggplot")
sns.lineplot(x="age",y="trtbps",hue="output",data=df)
plt.title("Effect of heart attack with increase in age and blood pressure")
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.style.use("ggplot")
sns.lineplot(x="age",y="thalachh",hue="output",data=df)
plt.title("Effect of heart attack with increase in age and maximum heart rate")
plt.show()

# %%
plt.figure(figsize=(18,8))
sns.heatmap(df.corr(),annot=True,cmap="plasma")  #using heatmap here

# %%
sns.scatterplot(y="chol",x="output",data=df)

# %%
sns.regplot(y="chol",x="output",data=df)

# %%
plt.figure(figsize=(12,8))
plt.style.use("ggplot")
sns.histplot(data = df, x = 'age', hue = 'output')
plt.title("Does age effect the heart attack")
plt.xlabel("Age")
plt.ylabel("Count")
plt.show()

# %%
#SO WE MADE THE FOLLOWING CONCLUSIONS:

#1.With increasing in age the cholestrol level of the body is increasing
#and if the body has high cholestrol level there is high chances of heart attack.

#2.With increasing in the age there is the low risk of heart attack:

#3.Increasing in heart rate will have high chances of heart attack:

#4.A heart attack occurs when the flow of blood to the heart is blocked
